# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("housing_1.csv")

# %%
data
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.17     37.76                  38         1764           397.0
# 1      -122.18     37.76                  50         1187           261.0
# 2      -122.18     37.76                  52          754           175.0
# 3      -122.18     37.76                  49         2308           452.0
# 4      -122.18     37.77                  27          909           236.0
# ..         ...       ...                 ...          ...             ...
# 294    -122.09     37.70                  30         1751           269.0
# 295    -122.08     37.71                  38         1663           295.0
# 296    -122.08     37.71                  38         3716           657.0
# 297    -122.08     37.70                  32         2718           447.0
# 298    -122.07     37.70                  39         1420           272.0
#
#      population  households  median_income  median_house_value ocean_proximity
# 0           987         354         2.4333               98200        NEAR BAY
# 1           907         246         1.9479               89500        NEAR BAY
# 2           447         165         3.9063               93800        NEAR BAY
# 3          1299         451         1.8407               96700        NEAR BAY
# 4           396         157         2.0786               97500        NEAR BAY
# ..          ...         ...            ...                 ...             ...
# 294         731         263         6.0050              263900        NEAR BAY
# 295         781         301         5.0519              227000        NEAR BAY
# 296        1784         652         4.8237              220900        NEAR BAY
# 297        1156         410         5.2497              259300        NEAR BAY
# 298         645         277         4.1250              232500        NEAR BAY
#
# [299 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           299 non-null    float64
#  1   latitude            299 non-null    float64
#  2   housing_median_age  299 non-null    int64
#  3   total_rooms         299 non-null    int64
#  4   total_bedrooms      296 non-null    float64
#  5   population          299 non-null    int64
#  6   households          299 non-null    int64
#  7   median_income       299 non-null    float64
#  8   median_house_value  299 non-null    int64
#  9   ocean_proximity     299 non-null    object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 23.5+ KB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296 entries, 0 to 298
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           296 non-null    float64
#  1   latitude            296 non-null    float64
#  2   housing_median_age  296 non-null    int64
#  3   total_rooms         296 non-null    int64
#  4   total_bedrooms      296 non-null    float64
#  5   population          296 non-null    int64
#  6   households          296 non-null    int64
#  7   median_income       296 non-null    float64
#  8   median_house_value  296 non-null    int64
#  9   ocean_proximity     296 non-null    object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 25.4+ KB

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.17     37.76                  38         1764           397.0
# 1      -122.18     37.76                  50         1187           261.0
# 2      -122.18     37.76                  52          754           175.0
# 3      -122.18     37.76                  49         2308           452.0
# 4      -122.18     37.77                  27          909           236.0
# ..         ...       ...                 ...          ...             ...
# 294    -122.09     37.70                  30         1751           269.0
# 295    -122.08     37.71                  38         1663           295.0
# 296    -122.08     37.71                  38         3716           657.0
# 297    -122.08     37.70                  32         2718           447.0
# 298    -122.07     37.70                  39         1420           272.0
#
#      population  households  median_income ocean_proximity
# 0           987         354         2.4333        NEAR BAY
# 1           907         246         1.9479        NEAR BAY
# 2           447         165         3.9063        NEAR BAY
# 3          1299         451         1.8407        NEAR BAY
# 4           396         157         2.0786        NEAR BAY
# ..          ...         ...            ...             ...
# 294         731         263         6.0050        NEAR BAY
# 295         781         301         5.0519        NEAR BAY
# 296        1784         652         4.8237        NEAR BAY
# 297        1156         410         5.2497        NEAR BAY
# 298         645         277         4.1250        NEAR BAY
#
# [296 rows x 9 columns]

# %%
y
# Out:
# 0       98200
# 1       89500
# 2       93800
# 3       96700
# 4       97500
#         ...
# 294    263900
# 295    227000
# 296    220900
# 297    259300
# 298    232500
# Name: median_house_value, Length: 296, dtype: int64

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.3)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 66     -122.13     37.75                  30          414            54.0
# 128    -122.27     37.88                  44         2252           592.0
# 70     -122.15     37.75                  40         1445           256.0
# 79     -122.17     37.74                  34         1223           281.0
# 1      -122.18     37.76                  50         1187           261.0
# ..         ...       ...                 ...          ...             ...
# 200    -122.27     37.85                  50         1279           300.0
# 55     -122.17     37.76                  40         1685           343.0
# 67     -122.13     37.75                  36          768            93.0
# 76     -122.15     37.74                  49         1325           277.0
# 54     -122.17     37.75                  47          998           211.0
#
#      population  households  median_income ocean_proximity  median_house_value
# 66          137          50         4.9750        NEAR BAY              311100
# 128         989         550         3.0132        NEAR BAY              272900
# 70          849         255         3.8913        NEAR BAY              126300
# 79          824         280         2.2917        NEAR BAY               92500
# 1           907         246         1.9479        NEAR BAY               89500
# ..          ...         ...            ...             ...                 ...
# 200         675         255         1.9028        NEAR BAY              150800
# 55          949         342         1.8426        NEAR BAY               94800
# 67          229          93         5.3602        NEAR BAY              330000
# 76          764         282         3.3125        NEAR BAY              118000
# 54          597         185         3.1587        NEAR BAY              100400
#
# [207 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 66     -122.13     37.75                  30     6.028279        4.007333
# 128    -122.27     37.88                  44     7.720018        6.385194
# 70     -122.15     37.75                  40     7.276556        5.549076
# 79     -122.17     37.74                  34     7.109879        5.641907
# 1      -122.18     37.76                  50     7.080026        5.568345
# ..         ...       ...                 ...          ...             ...
# 200    -122.27     37.85                  50     7.154615        5.707110
# 55     -122.17     37.76                  40     7.430114        5.840642
# 67     -122.13     37.75                  36     6.645091        4.543295
# 76     -122.15     37.74                  49     7.189922        5.627621
# 54     -122.17     37.75                  47     6.906755        5.356586
#
#      population  households  median_income  median_house_value  NEAR BAY
# 66     4.927254    3.931826         4.9750              311100         1
# 128    6.897705    6.311735         3.0132              272900         1
# 70     6.745236    5.545177         3.8913              126300         1
# 79     6.715383    5.638355         2.2917               92500         1
# 1      6.811244    5.509388         1.9479               89500         1
# ..          ...         ...            ...                 ...       ...
# 200    6.516193    5.545177         1.9028              150800         1
# 55     6.856462    5.837730         1.8426               94800         1
# 67     5.438079    4.543295         5.3602              330000         1
# 76     6.639876    5.645447         3.3125              118000         1
# 54     6.393591    5.225747         3.1587              100400         1
#
# [207 rows x 10 columns]

# %%
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='latitude',y='longitude',data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
sns.heatmap(train_data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
x_train_s=scaler.fit_transform(x_train)
reg=LinearRegression()
reg.fit(x_train_s,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
x_test_s=scaler.transform(x_test)

# %%
reg.score(x_test_s, y_test)
# Out:
# 0.7672133052284502

# %%
from sklearn.ensemble import RandomForestRegressor
forest= RandomForestRegressor()
forest.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s,y_test)
# Out:
# 0.9091175606286139

# %%
from sklearn.model_selection import GridSearchCV
forest=RandomForestRegressor()
param_grid={
    "n_estimators":[100,200,300],
    "min_samples_split":[2,4],
    "max_depth":[None,4,8]
}
grid_search=GridSearchCV(forest,param_grid,cv=5,
                        scoring="neg_mean_squared_error",
                        return_train_score=True)
grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=8, n_estimators=200)

# %%
grid_search.best_estimator_.score(x_test_s,y_test)
# Out:
# 0.9056414343268903
